# %% [markdown]
# # Assignment 02
#
# Dear Team,
#
# I hope you are doing GREAT!
#
# The assignment has two parts. The coding part has 5% value, and the YouTube presentation worthes 5%.
#
# The assignment is easy to follow yet needs the patience to solve each question at a time.
#
# **Note:**
#
# Please note that every question has 0.5 and it provides five out of total ten marks for the assignment.
#
# In short, 15 for coding + 5 for the video presentation = 20.

# %% [markdown]
# # Part A:
#
# In the beginning, the program checks if a file named "Score.txt" in a specific location in your Google Drive contains any score or not?
#
# If it does not contain any score, it shows the following message:
# "Welcome to your Math Game!"
#
# If there is any recorded score, e.g. 30, the program shows the following message:
# "I am happy to meet you again! Your last score was 30!"
#
# Next, the program randomly chooses two integer numbers and an operator, such as +, - or *. (You need to find a way how to generate random operator. It is not very difficault.)
#
# For example, the program chooses 7, 8, and +. Then it asks the user the following question:
# "What is the result of 7 + 8?"
#
# If the user enters a correct answer, the following message will show on the screen:
# "Congratulations! You are Pro!"
# And it adds one score to the user's achieved score.
#
# And if the user enters a wrong answer, the following message will show on the screen:
# "The correct answer is 15. Let's try another question :)"
# And it reduces one score from the user's achieved score.
#
# Then the program should ask you if you want to continue the game, showing the following text:
#  "Do you want to continue? (Y to continue, any other character to Exit)"
#
# In the following, I will guide you to enjoy your coding process, step by step:

# %%
# Please import random and string libraries.
# Please note that the empty cells are there for you to enter your code :)

# %%
import random 
import string

# %%
# Connect your Colab to your Google drive.
# Hint: Using dive.mount

# %%
from google.colab import drive
drive.mount("/content/drive") #enter your file location on drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1 Marks
# Now, we need to open a file that we save our score in it, called Score.txt.
# Please check if Score.txt contains anyting or not.
# If it does not contain anything, the program should show the following message:
# "Welcome to your Math Game!"
# If you have run the code before and there is any score saved into the file,
# the following message should appear:
# "I am happy to meet you again! Your last score was XXX!", which XXX is your 
# saved score from the previous attempt.
# Make sure that you check all the possible errors (Exception Handling)
#
# Some hints:
# For FileNotFoundError, please show "No file is found! We will make one for you. Welcome!"
# For OSError, please show "File found - error reading file!"
# For any other Exception, please show "An unexpected error occurred!""

# %%
try:
  file = open('/content/drive/My Drive/Score.txt', 'r')
  data = file.read()
  file.close()
  if data == "":
    print("Welcome to your Math Game!")
  else:
    print("I am happy to meet you again! Your last score was {}!".format(data))
except FileNotFoundError:
  print("No file is found! We will make one for you. Welcome!")
except OSError:
  print("File found - error reading file!")
except Exception:
  print("An unexpected error occurred!")
# Out:
# I am happy to meet you again! Your last score was -1!

# %%
# Define a global maxScore=0
# This variable will take care of number of correct and number of wrong answers

# %%
maxScore = 0

# %%
# 1 Marks
# Define a function, called  myMathTest that has the following parts:
# You need to callmaxScore here (your global variable) as you need to modify it 
# in this function.
#
# Define two random integers, e.g. variable a and variable b
# These two random integers are between 1 to 10.
# Imagine, in one run the random numbers for a, and b are 3 and 5 respectively.
#
# Define a mechanism that generates a random operator 
# (one of the following operators +, - or * )
# Imagine the random operator is *, so you need to calculate c=a*b
# Which would be c=3*5
# 
# Now, you need to ask the user the following question:
# What is the result of 3*5?
#
# If the user enters 15, the following message should appear:
# "Congratulations! You are Pro!"
# And you need to add 1 to your global maxScore.
#
# If the user enters a wrong answer, e.g. 10, 
# the following message should appear:
# "The correct answer is 15. Let's try another question :)"
# And you need to deduct 1 from your global maxScore.

# %%
def myMathTest():
  global maxScore
  a, b = random.randint(1, 10), random.randint(1, 10)
  o = random.choice("+-*")
  c = 0
  if o =='*': c = a * b
  elif o == '+': c = a + b
  else: c = a - b

  try:
    ans = int(input("What is the result of {}{}{}? =>".format(a,o,b)))
  except:
    print("Uhoh! Wrong Input...")
  
  if c == ans:
    print("Congratulations! You are Pro!")
    maxScore += 1
  else:
    print("The correct answer is {}. Let's try another question :)".format(c))
    maxScore -= 1

# %%
# 1 Marks
# Now, define an infinite loop (Hint: Using True as the condition) 
# and call myMathTest() as the first statement inside the loop.
# Then, every time ask the user if they want to continue playing or not, 
# asking the following question:
# "Do you want to continue? (Y to continue, any other character to Exit)"

# The game should continue as long as the user presses "y" or "Y".

# After the user entered any character, but "y" or "Y", 
# you should print the following messages:
# "Thank you for playing!"
# "You got XXX!"
# "WOW!"

# e.g. if the achieved score is 150, the messages would be as follows:
# "Thank you for playing!"
# "You got 150!"
# "WOW!"

# %%
while True:
  myMathTest()
  if input("Do you want to continue? (Y to continue, any other character to Exit) ").strip() not in 'yY':
    print("Thank you for playing!")
    print("You got {}!".format(maxScore))
    print("WOW!")
    break
# Out:
# What is the result of 8*10? =>80
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) y
# What is the result of 4-4? =>0
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) y
# What is the result of 10*8? =>80
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) y
# What is the result of 1*7? =>7
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) y
# What is the result of 1+10? =>11
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) y
# What is the result of 2*10? =>20
# Congratulations! You are Pro!
# Do you want to continue? (Y to continue, any other character to Exit) x
# Thank you for playing!
# You got 6!
# WOW!

# %% [markdown]
# One exmple:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Next:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you type Y... and playing one more round:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 0.2 Mark
# Then, save the achieved score in the "Score.txt" file.

# %%
try:
  file = open('/content/drive/My Drive/Score.txt', 'w')
  if data == "":
    file.write(str(maxScore))
  else:
    file.write(str(maxScore + int(data)))
    #comment above two lines to reset score to current at the end of each game.
    #this will add the previous score to current ans save
  file.close()
except OSError:
  print("File found - error reading file!")
except:
  print("An unexpected error occurred!")

# %% [markdown]
# # Part B:
# Part B is about solving a quadratic equation.

# %% [markdown]
# https://www.khanacademy.org/math/algebra/x2f8bb11595b61c86:quadratic-functions-equations/x2f8bb11595b61c86:quadratic-formula-a1/a/quadratic-formula-review

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here is a Quick Video that goes through the quadratic equation:
#
# https://www.youtube.com/watch?v=IlNAJl36-10

# %% [markdown]
# Please look at the statement in the above radical, which is b^2 - 4ac.
#
# We call  b^2 - 4ac, Discriminant.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here is a bit more information, if you want:
#
# https://www.mathsisfun.com/algebra/quadratic-equation.html

# %% [markdown]
# And here is another video, if you need to know more before coding:
#
# https://www.khanacademy.org/math/algebra/x2f8bb11595b61c86:quadratic-functions-equations/x2f8bb11595b61c86:quadratic-formula-a1/v/using-the-quadratic-formula

# %% [markdown]
# # Math Game Explanation:
#
# Now, you reviewed the Quadratic Equation concept.

# %%
# Now, you reviewed the Quadratic Equation concept.
# First, we type "Welcome to Quadratic Equation Game!"

# %%
print("Welcome to Quadratic Equation Game!")
# Out:
# Welcome to Quadratic Equation Game!

# %%
# Next, please show the Quadratic Equation as follows:
# "aX^2 + bX + C = 0"

# %%
print("aX^2 + bX + C = 0")
# Out:
# aX^2 + bX + C = 0

# %%
# 0.2 Mark
# Then, ask the user to enter a, b, and c, respectively.

# %%
a = int(input("Please, enter the value for a: "))
# Out:
# Please, enter the value for a: 1

# %%
b = int(input("Please, enter the value for b: "))
# Out:
# Please, enter the value for b: 5

# %%
c = int(input("Please, enter the value for c: "))
# Out:
# Please, enter the value for c: 6

# %%
# 0.2 Mark
# Now, please show the quadratic equation to the user, before start solving it:
# e.g. "Your Quadratic Equation is: 1X^2 + 5X + 6 = 0"

# %%
equation = "Your Quadratic Equation is: {}X^2 + {}X + {} = 0".format(a, b, c)

print(equation)
# Out:
# Your Quadratic Equation is: 1X^2 + 5X + 6 = 0

# %%
# 0.2 Mark
# Define a function, called discriminant that receives a, b, and c, and calculates the discriminant.

# %%
def discriminant(a,b,c):
  return (b*b - 4*a*c)

# %%
# 1 Marks
# Use the above function in the following part:
# If Discriminant is positive, we get two Real solutions.
# So, please print "We got two real solutions, which are X1, and X2"
# Sure, you calculate the value of X1, and X2.

# If Discriminant  is zero we get just ONE real solution (both answers are the same).
# So, please print "We got one real solution, which is X1"
# Sure, you calculate the value of X1.

# If Discriminant is negative we get a pair of Complex solutions.
# So, please print "The Discriminant is negative, we got a pair of Complex solutions."
# You do not need to show the complex solutions :)

# Note: You need to import math library, and calculate the square root of 
# discriminant for the case that you have two real solutions.

# %%
import math

response = ""

d = math.sqrt(discriminant(a,b,c))
if d > 0:
  x1 = (d - b)/(2*a)
  x2 = -(d + b)/(2*a)
  response = "We got two real solutions, which are {}, and {}".format(x1, x2)

elif d == 0:
  x1 = -b / (2*a)
  response = "We got one real solution, which is {}".format(x1)

else:
  response = "The Discriminant is negative, we got a pair of Complex solutions."


print(response)
ansToWrite = equation + '\n' + response
# Out:
# We got two real solutions, which are -2.0, and -3.0

# %%
# 0.2 Mark
# Finally, save the above two messages into a file, called "QuadEqu.txt"
# e.g.
# Your Quadratic Equation is: 1X^2 + 5X + 6 = 0
# We got two real solutions,, which are -2.0, and -3.0

# %%
with open("QuadEqu.txt", 'w')as file:
  file.write(ansToWrite)
  file.write('\n')
  file.close()

# change 'w' in line 1 to 'a' to append to file

# %% [markdown]
# ---
# # Deliverables:
# 1. Please, submit the current ipynb file with your responses.
# 2. Please record and upload to YouTube a 5 to 10 minutes video recorded clip, describing all you have done. If you go beyond 10 minutes, it is fine. The mentioned time range is to show how the scale of the assignment could be.
# Then submit the link to the uploaded YouTube video in the **Text Submision section** (see image below).
#
# ![image.png](https://i.ibb.co/gjW5wYC/bb-submission-instructions.png)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Summary:**
#
# In short, what we need to submit are:
#
# a)	The current **ipynb file** that contains all the code (15 marks).
#
# b)	The **YouTube link** of your recorded video in the **Text Submission section** (5 marks).

# %% [markdown]
# Wish you only the best, Dear Team Members!
#
# Reza
